# %% [markdown]
# ## Transit score

# %%
## Libraries and key
import urllib.request
import json
import requests
import sys

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key=api_key_1)

# %% [markdown]
# ## Transit API Calls
#
# There are six available API calls from the base URL http://transit.walkscore.com:
#
# <table><tr><td>Name</td><td >URL	</td><td>Description</td></tr>
# <tr><td>score</td><td>/transit/score/	</td><td>Returns the Transit Score for a given location.</td></tr>
# <tr><td>stop search</td><td>	/transit/search/stops/</td><td>	Returns information about stops near a given location.</td></tr>
# <tr><td>network search</td><td>	/transit/search/network/	</td><td>Returns connected stops and routes near a given location.</td></tr>
# <tr><td>stop detail</td><td>	/transit/stop/ID/</td><td>	Returns details for a single stop.</td></tr>
# <tr><td>route detail</td><td>	/transit/route/ID/	</td><td>Returns details for a single route.</td></tr>
# <tr><td>supported cities</td><td>	/transit/supported/cities/</td><td>	Returns a list of cities for which scores are available.</td></tr>
# </table>
# All Transit API calls return JSON information and the HTTP 200 status code on success, or return an HTTP 4xx status code on failure.
#
# All Transit API calls require an API Key parameter, wsapikey. If you do not include this parameter, you will receive a 4xx status code. If you are over quota, you will also receive a 4xx status code.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import sys

# %% [markdown]
# ## Since Lat and Lon are mandatory fields for walkscore API, we will derive it using google api as below

# %% [markdown]
# ## Get latitude and longitude of a given address

# %%
# Simplest way to get the lat, long of any address.

# Using Python requests and the Google Maps Geocoding API.

import requests

GOOGLE_MAPS_API_URL = 'http://maps.googleapis.com/maps/api/geocode/json'

params = {
    'address': '45202', # 
    'sensor': 'false',
    'region': 'USA'
}

# Do the request and get the response data
req = requests.get(GOOGLE_MAPS_API_URL, params=params)
res = req.json()

res

# Use the first result
result = res['results'][0]

geodata = dict()
geodata['lat'] = result['geometry']['location']['lat']
geodata['lng'] = result['geometry']['location']['lng']
geodata['address'] = result['formatted_address']

print('{address}. (lat, lng) = ({lat}, {lng})'.format(**geodata))
# Out:
# Cincinnati, OH 45202, USA. (lat, lng) = (39.1031971, -84.5064881)

# %%
api_key = 'f066ffbcd095ecd362043241930e1a6b'

# %% [markdown]
# ###  1. Transit Score

# %%
#http://transit.walkscore.com/transit/score/?lat=47.6101359&lon=-122.3420567&city=Seattle&state=WA&wsapikey=your_key
#http://transit.walkscore.com/transit/score/?lat=47.6101359&lon=-122.3420567&city=Seattle&state=WA&wsapikey=
    # mandatory values
#TRANSIT_BASE_URL = /transit/route/ID/

BASE_URL = 'http://transit.walkscore.com/transit'
city = 'Seattle'
state = 'WA'
lat = 47.6101359
lon =-122.3420567
#api_key = 

api_url = ("{}/score/?lat={}&lon={}&city={}&state={}&wsapikey={}&research=yes").format(BASE_URL, lat, lon, city, state, api_key)
api_url
# Out:
# 'http://transit.walkscore.com/transit/score/?lat=47.6101359&lon=-122.3420567&city=Seattle&state=WA&wsapikey=f066ffbcd095ecd362043241930e1a6b&research=yes'

# %%
r = requests.get(api_url)
#res = r.json()
print(r)
# Out:
# <Response [400]>

# %%
if r.status_code != 200:
    print('HTTP status code {} received, program terminated.'.format(r.status_code))
else:
    #Convert rest of type dict to json object
    res = r.json()
    #print(res)
    if 'transit_score' not in res:
        print("Tansit Score = Data not available")
    else:
        print("Tranist detatils for City: ",city)
        print("Tansit Score: ", res['transit_score'] , ", ",res['description'])
        print("Public Transportation details: ", res['summary'],)
# Out:
# HTTP status code 400 received, program terminated.

# %% [markdown]
# ## 2.  Search Stops

# %%
#TRANSIT_BASE_URL = /transit/route/ID/ search/stops/

BASE_URL = 'http://transit.walkscore.com/transit'
city = 'Seattle'
state = 'WA'
lat = 47.6101359
lon =-122.3420567
#api_key = 

api_url = ("{}/search/stops/?lat={}&lon={}&city={}&state={}&wsapikey={}&research=yes").format(BASE_URL, lat, lon, city, state, api_key)
api_url

r = requests.get(api_url)
res = r.json()
print(res)
# Out:
# [{'distance': 0.08946838246064352, 'name': '2nd Ave & Stewart St', 'summary_text': '2nd Ave & Stewart St (0.1 mi)\t111, 114, 212, 214, 216, 217, 218, 219, ...', 'summary_html': '<span class="walkscore"><span class="stop">2nd Ave &amp; Stewart St</span> <span class="distance">(0.1 mi)</span> <span class="Bus">111, 114, 212, 214, 216, 217, 218, 219, &#8230;</span></span>', 'route_summary': [{'category': 'Bus', 'agency_url': 'http://metro.kingcounty.gov', 'agency': 'Metro Transit', 'id': '88346e903b6ce6c0bb34201f9b682446025d7b63', 'name': '111'}, {'category': 'Bus', 'agency_url': 'http://metro.kingcounty.gov', 'agency': 'Metro Transit', 'id': 'a9f9995019db0611eddd39303ff83c4facf1fa97', 'name': '114'}, {'category': 'Bus', 'agency_url': 'http://metro.kingcounty.gov', 'agency': 'Metro Transit', 'id': '39ea1b61061f93614f4cc289303f48e1dfa16d22', 'name': '212'}, {'category': 'Bus', 'agency_url': 'http://metro.kingcounty.gov', 'agency': 'Metro Transit', 'id': '0d679c96a22aefe5f4d109569fbb0cb4787b6e0e', 'name': '214'}, {'category': 'Bus', 'agency_url': 'http://metro.kingcounty.gov', 'agency': 'Metro Transit', 'id': 'be3cff03bd74a92a5496c12da9e2ed42d6e32e9c', 'name': '216'}, {'category': 'Bus', 'agency_url': 'http://metro.kingcounty.gov', 'agency': 'Metro Transit', 'id': '0bad9c8a42ab7f2ea1c861888fc0000a92a569c7', 'name': '217'}, {'category': 'Bus', 'agency_url': 'http://metro.kingcounty.gov', 'agency': 'Metro Transit', 'id': '810b1d103107916d6fc65681b575fe5c37ff2fb8', 'name': '218'}, {'category': 'Bus', 'agency_url': 'http://metro.kingcounty.gov', 'agency': 'Metro Transit', 'id': '4f8891566ee634b49bb00dcb8220d6bd57096d6a', 'name': '219'}, {'category': 'Bus', 'agency_url': 'http://www.soundtransit.org/', 'agency': 'Sound Transit', 'id': '300b1d6b8f4e8761f24f2bef554abb22f89219d1', 'name': '554'}], 'lon': -122.340332, 'lat': 47.6107025, 'id': 'db09c7cebc9ca1bcb0395f6e103ca7ed6c15881a'}, {'distance': 0.08948353783045644, 'name': '2nd Ave & Stewart St', 'summary_text': '2nd Ave & Stewart St (0.1 mi)\t402 Lynnwood - Seattle, 405 Edmonds P&amp;R - Seattle, 410 Mariner P&amp;R - Seattle, 412 Silver Firs - Seattle, 413 Swamp Creek P&amp;R - Seattle, 415 North Lynnwood - Seattle, 416 Edmonds - Seattle, 417 Mukilteo - Seattle, ...', 'summary_html': '<span class="walkscore"><span class="stop">2nd Ave &amp; Stewart St</span> <span class="distance">(0.1 mi)</span> <span class="Bus">402 Lynnwood - Seattle, 405 Edmonds P&amp;R - Seattle, 410 Mariner P&amp;R - Seattle, 412 Silver Firs - Seattle, 413 Swamp Creek P&amp;R - Seattle, 415 North Lynnwood - Seattle, 416 Edmonds - Seattle, 417 Mukilteo - Seattle, &#8230;</span></span>', 'route_summary': [{'category': 'Bus', 'agency_url': 'http://www.communitytransit.org/', 'agency': 'Community Transit', 'id': '4165c28d940bc1a1434a5c06cc30ecd4df585b31', 'name': '402 Lynnwood - Seattle'}, {'category': 'Bus', 'agency_url': 'http://www.communitytransit.org/', 'agency': 'Community Transit', 'id': '1301595034f647e8cfa404703b2fe55f203c87fd', 'name': '405 Edmonds P&R - Seattle'}, {'category': 'Bus', 'agency_url': 'http://www.communitytransit.org/', 'agency': 'Community Transit', 'id': 'dbfc793902fc5d117d37415e2e4dbd12fe6736ec', 'name': '410 Mariner P&R - Seattle'}, {'category': 'Bus', 'agency_url': 'http://www.communitytransit.org/', 'agency': 'Community Transit', 'id': 'f9f0ab13a76301f602af1ae829ae49c44c5e31bb', 'name': '412 Silver Firs - Seattle'}, {'category': 'Bus', 'agency_url': 'http://www.communitytransit.org/', 'agency': 'Community Transit', 'id': '75d7786ce1b146665a11fb86d922e8f4a49ed0ae', 'name': '413 Swamp Creek P&R - Seattle'}, {'category': 'Bus', 'agency_url': 'http://www.communitytransit.org/', 'agency': 'Community Transit', 'id': 'f2a475305483b63471dd175f99a9c3f50c105728', 'name': '415 North Lynnwood - Seattle'}, {'category': 'Bus', 'agency_url': 'http://www.communitytransit.org/', 'agency': 'Community Transit', 'id': '3b4f3accabbb3458276987a9e9a9bf77e21b2bc1', 'name': '416 Edmonds - Seattle'}, {'category ...

# %% [markdown]
# ## 3. Supported cities

# %%
#/transit/supported/cities/
BASE_URL = 'http://transit.walkscore.com/transit'
city = 'Seattle'
state = 'WA'
lat = 47.6101359
lon =-122.3420567
#api_key = 

api_url = ("{}/supported/cities/?lat={}&lon={}&city={}&state={}&wsapikey={}&research=yes").format(BASE_URL, lat, lon, city, state, api_key)
api_url

r = requests.get(api_url)
r
# Out:
# <Response [200]>

# %%
res = r.json()
print(res)
# Out:
# [{'city': 'blyn', 'state': 'wa', 'population': 162}, {'city': 'ashwaubenon', 'state': 'wi', 'population': 16963}, {'city': 'monterey', 'state': 'ca', 'population': 27810}, {'city': 'west little river', 'state': 'fl', 'population': 34699}, {'city': 'kirkwood', 'state': 'mo', 'population': 27540}, {'city': 'stoneham', 'state': 'ma', 'population': 21378}, {'city': 'moncton', 'country': 'ca', 'population': 69074}, {'city': 'hazelwood', 'state': 'mo', 'population': 25703}, {'city': 'la mesa', 'state': 'ca', 'population': 57065}, {'city': 'layton', 'state': 'ut', 'population': 67311}, {'city': 'blue mountains', 'country': 'au', 'population': 28769}, {'city': 'sand springs', 'state': 'ok', 'population': 18906}, {'city': 'burke centre', 'state': 'va', 'population': 17326}, {'city': 'toronto', 'country': 'ca', 'population': 2503281}, {'city': 'dakota ridge', 'state': 'co', 'population': 32005}, {'city': 'cleveland', 'state': 'oh', 'population': 433748}, {'city': 'commerce city', 'state': 'co', 'population': 45913}, {'city': 'taylorsville', 'state': 'ut', 'population': 58653}, {'city': 'avenel', 'state': 'nj', 'population': 17011}, {'city': 'mountain view', 'state': 'ca', 'population': 70708}, {'city': 'sioux falls', 'state': 'sd', 'population': 153888}, {'city': 'shaker heights', 'state': 'oh', 'population': 28448}, {'city': 'squamish', 'country': 'ca', 'population': 17158}, {'city': 'makakilo', 'state': 'hi', 'population': 18248}, {'city': 'azusa', 'state': 'ca', 'population': 46361}, {'city': 'miami lakes', 'state': 'fl', 'population': 22688}, {'city': 'lincolnia', 'state': 'va', 'population': 22855}, {'city': 'barnstable town', 'state': 'ma', 'population': 45193}, {'city': 'lansing', 'state': 'mi', 'population': 114297}, {'city': 'niles', 'state': 'il', 'population': 29803}, {'city': 'cypress', 'state': 'ca', 'population': 47800}, {'city': 'barstow', 'state': 'ca', 'population': 22639}, {'city': 'new brunswick', 'state': 'nj', 'population': 55181}, {'city': 'oak grove', 'state': 'or', 'population': 16629}, {'city': 'winnipeg', 'country': 'ca', 'population': 633451}, {'city': 'clearwater', 'state': 'fl', 'population': 106592}, {'city': 'northglenn', 'state': 'co', 'population': 35789}, {'city': 'santa monica', 'state': 'ca', 'population': 89736}, {'city': 'loma linda', 'state': 'ca', 'population': 23247}, {'city': 'south holland', 'state': 'il', 'population': 22030}, {'city': 'thunder bay', 'country': 'ca', 'population': 108359}, {'city': 'knoxville', 'state': 'tn', 'population': 178874}, {'city': 'quilcene', 'state': 'wa', 'population': 591}, {'city': 'concord', 'state': 'nc', 'population': 79066}, {'city': 'fitchburg', 'state': 'ma', 'population': 40318}, {'city': 'nanaimo', 'country': 'ca', 'population': 83810}, {'city': 'rutherford', 'state': 'nj', 'population': 18061}, {'city': 'hampton', 'state': 'va', 'population': 145494}, {'city': 'auburn', 'state': 'wa', 'population': 70028}, {'city': 'st petersburg', 'state': 'fl', 'population': 248232}, {'city': 'inglewood', 'state': 'ca', 'population': 109673}, {'city': 'new york', 'state': 'ny', 'population': 8363710}, {'city': 'mount vernon', 'state': 'ny', 'population': 67292}, {'city': 'florence', 'state': 'ky', 'population': 29951}, {'city': 'astoria', 'state': 'or', 'population': 10045}, {'city': 'chicago', 'state': 'il', 'population': 2853114}, {'city': 'oakdale', 'state': 'mn', 'population': 27378}, {'city': 'elmwood park', 'state': 'il', 'population': 24883}, {'city': 'reno', 'state': 'nv', 'population': 180480}, {'city': 'glendale', 'state': 'ca', 'population': 191719}, {'city': 'kirkland', 'state': 'wa', 'population': 45054}, {'city': 'highland park', 'state': 'il', 'population': 33492}, {'city': 'fountainebleau', 'state': 'fl', 'population': 59764}, {'city': 'kitchener', 'country': 'ca', 'population': 204668}, {'city': 'pleasantville', 'state': 'nj', 'population': 20249}, {'city': 'north valley stream', 'state': 'ny', 'population': 16628}, {'city': 'fort lee', 'state': 'nj',  ...

# %% [markdown]
# ## 4. Search network: Returns connected stops and routes near a given location.

# %%
#/transit/search/network/
BASE_URL = 'http://transit.walkscore.com/transit'
city = 'Seattle'
state = 'WA'
lat = 47.6101359
lon =-122.3420567
#api_key = 

api_url = ("{}/search/network/?lat={}&lon={}&city={}&state={}&wsapikey={}&research=yes").format(BASE_URL, lat, lon, city, state, api_key)
api_url

r = requests.get(api_url)
r
# Out:
# <Response [200]>

# %%
res = r.json()
print(res)
# Out:
# {'routes': {'f9f0ab13a76301f602af1ae829ae49c44c5e31bb': {'category': 'Bus', 'stop_ids': ['0225fc22ab8588db38cc157bdb6e032dc9588480', '1d607047ad8bf67785a23ad0c1f7491232742530', '6fac09e00c00685be3867163c01e1b4e3a8b64fb', '2c895a09d539f81a9673361c8b0a652319957cee', 'a16a48b5b4485047f8c6bf486fe735ff073e58ff', 'b02873aae620c1356ae0eaae8a0adff9e3fe74a5', '51c471177f17571d89fd8a0d5fdbb098dbf8938d', '938cb6fd36b0a635414bb2665d38d0a625849cdb', '86f3610d0c45671b7807e4f77e875f352817ac56', '9570bebfe2279e53cd1ebf39bbcfd0140d10bb3b', '4225496ba308dc2508e893fc3ba4f4a8676019de', '76b01e263fa4e1bbef0e4f1561d05df1e57f07eb', 'f9a82ebcec06c7f356170099ff21e182b11b37c4', '90a78cabc544026dcfe31f0204d4c3a1d9dd3a74', '68063fa3b35b4a060b532c698d0e7f9e53bc7ce8', '39ab9ea500b6abdbf4ff2faff4c02b34b9bbd2bd', '7ef3095c1035580250d858294be9c95487efee69', '12363c984cd3e71450711f957b71bc08837dbe73', 'bca726d82f1d19dd86f9a4f24f8342aae1eccdf9', '629e58ddd481c83ddcb9758e5369a0e8188e5530', '7cf80ef358d003ff9c39f2cb16938d72fda92645', 'cdc19bab052dd566e15c058509f58c6d1693bcfc', 'fab90cbe32ca5ea8163acd13c565ffc24e6efd4f', '3389641fc256db71008ec9b1f7fab1be10df24c8', 'aec30ade08a1769b7be9070ae57b02a7d97f6ae5', '8d1664dd95116f59a55d0aa56478ab390bd68fb5', '85cb09464fdf5061163a6f97d91d4a35547946fa', '578b202a8bd7a2662079af1a33c8849544600e5e', 'd42f43bab9167c25719d04c64c0e6ce4326031b7', '6573baa7a29e1ed3a7a9774f32c5273229cd370b', 'db8d766aadc79b42c5bd1af15f4bb5181d25f126', '86373a882a69f86590c7fdf11d4b49271129dbd7', '1c249527e31d80cb0749d9b4ed0a7e5b5e9b3cde', 'cf404cb59f72e723f40f14517a8019a34502c4fb', '8693120b0efce8d337db35eac4f6946799cfcc80', 'dbd980f6a99ee30ec6b52c9a7d3f10bfaf13f324', '628082f94b9c24e3e5c5c09b3eb3953224c682f8', 'd20edcf13e08e1adfad5d439965ac0260869d08b', 'c681a8174388d7a14246a412b6b43a5c582b2648', '087ace2fe29e1ee440bb126aba997991a73188f3', '0108ce9e21619821e486a35beec10839152ce14d', 'b19750fa8c37c96110b8c29e1635f87938ce5078', 'fe9538b52ea93befaa4bfe471af2a339978e1523', 'daefa48e4e809552b884b45ccc84707abe16cd11', '573e546c3c4a969ef97d17145630d047a02707cf', '26db04403e0393a903400dd25ee5f967d930bff4', '90fe9b9a394597193d3d93f2a0a7f7a5c7f1218f', '5ab4cc2e1dd25a650b0a84f9fceb837f062429a4', 'bf63b81650edb877f49274edc0ae6e857672b6f7', 'd3f6b0f38eaf8b56adfd731b3a0395638a3a39bb', 'da45311523ee0aef4820783123afd6b7ea9a32c5', '589bd7fc20b0ced052353627052abadd5998490c', '168929d7b1ea21a382e00309a500c2354fbb459f', 'e92f80012dff623a163c9ab7f4bd4d45df9b939b', 'ca5b80aa8626d83bd7945579315912d0723307d3', 'e217102304da3a667d87730ed8bfb283ee5476d9'], 'name': '412 Silver Firs - Seattle', 'agency_url': 'http://www.communitytransit.org/', 'agency': 'Community Transit', 'id': 'f9f0ab13a76301f602af1ae829ae49c44c5e31bb'}, 'f62ba446378ede193368c89d58f3aea559771113': {'category': 'Bus', 'stop_ids': ['e78b0435c6759aba988c6dc53102c5cab96135a3', '8ac0cd7b59f1bc7c63c79491c719a157b16ea87b', '78daf7e487b26db724936a5c11de26502b4a4b0b', 'a264a7aba66cb530347e0fba739033d98b410ec6', '6fe24ef6072ae720ff3c8de9f0f02ba49c7f9e11', '90d58c25087295d1fff9d6dbb64b3c6bb941dbd4', 'e4c766c69be2d90bbf51a67b63a7a95dc513e46c', '20e6b5f2b5822b40ed26f873f4c4b02a00fcc9d4', '4163f4922068945267b76c65e5c72554b74e130d', 'cf7b900164c87a2cb21353b9e26375fc0f6bf510', 'e46fa8561d2edad5547596dc9a59e1cad2be85b2', '43fd091525834ee56c1ccb7e5528b44f808ac4f0', 'ca9176ca76709b57152085eca74825b6b54e7ebc', '26d3ac4ecd3790b4c7cc04e9d08b8204321705af', '8e018c5f21224d24ebf8b40963a5c61b2b60fa0a', '90ce35c8c0edfe8e56edc2e965b57a77a7d7c4ea', '2f24a07e0d6b18d1c6e2ac4a424da578a19e55a5', '2ccf479a3e23adeb0b82216cb94a8ee8adda9328', 'df6e9d3911344875611df0823b97347efebb8a60', '4fc4e9d53aa139b415cb0af2881f8369b2d0e03c', 'e4498cc86e3fbf0bfd5efebb8a46aac7db1f0527', '824477671b91dec70b0223d3efa93ca0eacc787c', 'e2f4420e12a5d419d202cb6459097f85290040f3', 'dde494558bbbea44ee820be454783fe29af50d91', 'e01dd2d4a70ca06e9ea1556d0b00720f895c7f86', '60744adb0b13d041b90d05be51e7501257813aac', 'ad9563c85d0d41e7837b9b5da2ba315a46331609', '572dc1c33dc ...

# %% [markdown]
# ## 5. Search Stops - ID based search
# https://www.walkscore.com/professional/public-transit-api.php#stop

# %%
#/transit/
#http://transit.walkscore.com/transit/stop/s17737/?wsapikey=your_key

BASE_URL = 'http://transit.walkscore.com/transit'
city = 'Seattle'
state = 'WA'
lat = 47.6101359
lon =-122.3420567
#api_key = 

api_url = ("{}/stop/{}/?wsapikey={}").format(BASE_URL, 's10644', api_key)
print(api_url)

r = requests.get(api_url)
r
# Out:
# http://transit.walkscore.com/transit/stop/s10644/?wsapikey=f066ffbcd095ecd362043241930e1a6b
# <Response [400]>
